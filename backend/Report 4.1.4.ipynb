# %%
import ir_datasets
clinicaltrials_2021 = ir_datasets.load("clinicaltrials/2021/trec-ct-2021")

print("clinicaltrials_2021:   ")
print(clinicaltrials_2021)
print()
print("clinicaltrials_2021.docs_cls()._fields:   ")
print(clinicaltrials_2021.docs_cls()._fields)
print()
print("clinicaltrials_2021.docs_cls().__annotations__:   ")
print(clinicaltrials_2021.docs_cls().__annotations__)
print()
print("clinicaltrials_2021.docs_metadata():   ")
print(clinicaltrials_2021.docs_metadata())
print()
print("clinicaltrials_2021.docs_metadata()['count']:   ")
print(clinicaltrials_2021.docs_metadata()['count'])
print()
print("clinicaltrials_2021.has_queries():   ")
print(clinicaltrials_2021.has_queries())
print()
print("clinicaltrials_2021.queries_count():   ")
print(clinicaltrials_2021.queries_count())
print()
print("clinicaltrials_2021.has_qrels(:   ")
print(clinicaltrials_2021.has_qrels())
print()
print("clinicaltrials_2021.qrels_count():   ")
print(clinicaltrials_2021.qrels_count())
# Out:
# clinicaltrials_2021:
# Dataset(id='clinicaltrials/2021/trec-ct-2021', provides=['docs', 'queries', 'qrels'])
#
# clinicaltrials_2021.docs_cls()._fields:
# ('doc_id', 'title', 'condition', 'summary', 'detailed_description', 'eligibility')
#
# clinicaltrials_2021.docs_cls().__annotations__:
# {'doc_id': <class 'str'>, 'title': <class 'str'>, 'condition': <class 'str'>, 'summary': <class 'str'>, 'detailed_description': <class 'str'>, 'eligibility': <class 'str'>}
#
# clinicaltrials_2021.docs_metadata():
# {'count': 375580, 'fields': {'doc_id': {'max_len': 11, 'common_prefix': 'NCT0'}}}
#
# clinicaltrials_2021.docs_metadata()['count']:
# 375580
#
# clinicaltrials_2021.has_queries():
# True
#
# clinicaltrials_2021.queries_count():
# 75
#
# clinicaltrials_2021.has_qrels(:
# True
#
# clinicaltrials_2021.qrels_count():
# 35832

# %%
import ir_datasets
antiqueDataset = ir_datasets.load("antique/train")


print("antiqueDataset:   ")
print(antiqueDataset)
print()
print("antiqueDataset.docs_cls()._fields:   ")
print(antiqueDataset.docs_cls()._fields)
print()
print("antiqueDataset.docs_cls().__annotations__:   ")
print(antiqueDataset.docs_cls().__annotations__)
print()
print("antiqueDataset.docs_metadata():   ")
print(antiqueDataset.docs_metadata())
print()
print("antiqueDataset.docs_metadata()['count']:   ")
print(antiqueDataset.docs_metadata()['count'])
print()
print("antiqueDataset.has_queries():   ")
print(antiqueDataset.has_queries())
print()
print("antiqueDataset.queries_count():   ")
print(antiqueDataset.queries_count())
print()
print("antiqueDataset.has_qrels(:   ")
print(antiqueDataset.has_qrels())
print()
print("antiqueDataset.qrels_count():   ")
print(antiqueDataset.qrels_count())
# Out:
# antiqueDataset:
# Dataset(id='antique/train', provides=['docs', 'queries', 'qrels'])
#
# antiqueDataset.docs_cls()._fields:
# ('doc_id', 'text')
#
# antiqueDataset.docs_cls().__annotations__:
# {'doc_id': <class 'str'>, 'text': <class 'str'>}
#
# antiqueDataset.docs_metadata():
# {'count': 403666, 'fields': {'doc_id': {'max_len': 10, 'common_prefix': ''}}}
#
# antiqueDataset.docs_metadata()['count']:
# 403666
#
# antiqueDataset.has_queries():
# True
#
# antiqueDataset.queries_count():
# 2426
#
# antiqueDataset.has_qrels(:
# True
#
# antiqueDataset.qrels_count():
# 27422

# %%
import time

def time_it(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"Execution time: {elapsed_time:.3f} seconds")
        return result

    return wrapper

@time_it
def my_function():
    time.sleep(3)
my_function()
# Out:
# Execution time: 3.001 seconds

# %%
antique_doc_file = 'Datasets\\antique\\collection.tsv'
chunksize = 200001
index_row_in_XML = 0
name_clinicaltrials = "clinicaltrials"
name_antique = "antique"
antiqueDataset_value = "antiqueDataset"  #use inside string as dataset value
clinicaltrials_2021_value = "clinicaltrials_2021"  #use inside string as dataset value
level_list = [1, 2, 3]
level_list_ = [3]
path_clinicaltrials = "Report\\newDataset\\part "
path_antique = "Report\\newDataset\\part "
doc_and_qry_and_qrl = ["query", "qrel", "document"]
doc_and_qry_and_qrl_ = [ "document"]

# %%
clusterd_path = "Report\\Clusterd\\"
clusterd_ٍspecial_path = "Report\\Clusterd Special\\"
doc_and_qry = ["query", "document"]

# %%
import os

def create_directory(directory_path):
    if not os.path.exists(directory_path):
        try:
            os.makedirs(directory_path)
            print(f"Directory created: {directory_path}")
        except OSError as error:
            print(f"Failed to create directory: {error}")

# %%
import xml.etree.ElementTree as ET
def create_clustersd(doc_and_qry_and_qrl, path, Dataset, name):
    for doc_or_qry_or_qrl in doc_and_qry_and_qrl:
        if doc_or_qry_or_qrl == "qrel":
            DatasetName1 = path + name +"\\qrels\\"
            items = Dataset.qrels_cls()._fields
        elif doc_or_qry_or_qrl == "query":
            DatasetName1 = path + name +"\\queris\\"
            items = Dataset.queries_cls()._fields
        else:
            DatasetName1 = path + name +"\\documents\\"
            items = Dataset.docs_cls()._fields
            
        is_id = True
        print("---------------------------")
        print(DatasetName1 + str(is_id))
        print("---------------------------")

        for item in items:
            if is_id:
                is_id = False
                print("---------------------------")
                print(DatasetName1 + str(is_id))
                print("---------------------------")
                continue
            DatasetName2 = DatasetName1 + item + "\\"
            for char1 in range(ord('a'), ord('z') + 1):
                DatasetName_ = DatasetName2 + chr(char1)
                create_directory(DatasetName_)
                for char2 in range(ord('a'), ord('z') + 1):
                    DatasetName = DatasetName_ + "\\"+ chr(char2) + ".xml"
                    root = ET.Element(chr(char1)+chr(char2))  # Create the root element
                    with open(DatasetName, 'w', encoding='utf-8') as file:
                        file.write('<?xml version="1.0" encoding="utf-8"?>\n')
                    tree = ET.tostring(root)
                    with open(DatasetName, 'a') as file:
                        file.write(tree.decode() + '\n')

# %%
create_clustersd(doc_and_qry, clusterd_path, antiqueDataset, name_antique)
create_clustersd(doc_and_qry, clusterd_path, clinicaltrials_2021, name_clinicaltrials)
# Out:
# ---------------------------
# Report\Clusterd\antique\queris\True
# ---------------------------
# ---------------------------
# Report\Clusterd\antique\queris\False
# ---------------------------
# Directory created: Report\Clusterd\antique\queris\text\a
# Directory created: Report\Clusterd\antique\queris\text\b
# Directory created: Report\Clusterd\antique\queris\text\c
# Directory created: Report\Clusterd\antique\queris\text\d
# Directory created: Report\Clusterd\antique\queris\text\e
# Directory created: Report\Clusterd\antique\queris\text\f
# Directory created: Report\Clusterd\antique\queris\text\g
# Directory created: Report\Clusterd\antique\queris\text\h
# Directory created: Report\Clusterd\antique\queris\text\i
# Directory created: Report\Clusterd\antique\queris\text\j
# Directory created: Report\Clusterd\antique\queris\text\k
# Directory created: Report\Clusterd\antique\queris\text\l
# Directory created: Report\Clusterd\antique\queris\text\m
# Directory created: Report\Clusterd\antique\queris\text\n
# Directory created: Report\Clusterd\antique\queris\text\o
# Directory created: Report\Clusterd\antique\queris\text\p
# Directory created: Report\Clusterd\antique\queris\text\q
# Directory created: Report\Clusterd\antique\queris\text\r
# Directory created: Report\Clusterd\antique\queris\text\s
# Directory created: Report\Clusterd\antique\queris\text\t
# Directory created: Report\Clusterd\antique\queris\text\u
# Directory created: Report\Clusterd\antique\queris\text\v
# Directory created: Report\Clusterd\antique\queris\text\w
# Directory created: Report\Clusterd\antique\queris\text\x
# Directory created: Report\Clusterd\antique\queris\text\y
# Directory created: Report\Clusterd\antique\queris\text\z
# ---------------------------
# Report\Clusterd\antique\documents\True
# ---------------------------
# ---------------------------
# Report\Clusterd\antique\documents\False
# ---------------------------
# Directory created: Report\Clusterd\antique\documents\text\a
# Directory created: Report\Clusterd\antique\documents\text\b
# Directory created: Report\Clusterd\antique\documents\text\c
# Directory created: Report\Clusterd\antique\documents\text\d
# Directory created: Report\Clusterd\antique\documents\text\e
# Directory created: Report\Clusterd\antique\documents\text\f
# Directory created: Report\Clusterd\antique\documents\text\g
# Directory created: Report\Clusterd\antique\documents\text\h
# Directory created: Report\Clusterd\antique\documents\text\i
# Directory created: Report\Clusterd\antique\documents\text\j
# Directory created: Report\Clusterd\antique\documents\text\k
# Directory created: Report\Clusterd\antique\documents\text\l
# Directory created: Report\Clusterd\antique\documents\text\m
# Directory created: Report\Clusterd\antique\documents\text\n
# Directory created: Report\Clusterd\antique\documents\text\o
# Directory created: Report\Clusterd\antique\documents\text\p
# Directory created: Report\Clusterd\antique\documents\text\q
# Directory created: Report\Clusterd\antique\documents\text\r
# Directory created: Report\Clusterd\antique\documents\text\s
# Directory created: Report\Clusterd\antique\documents\text\t
# Directory created: Report\Clusterd\antique\documents\text\u
# Directory created: Report\Clusterd\antique\documents\text\v
# Directory created: Report\Clusterd\antique\documents\text\w
# Directory created: Report\Clusterd\antique\documents\text\x
# Directory created: Report\Clusterd\antique\documents\text\y
# Directory created: Report\Clusterd\antique\documents\text\z
# ---------------------------
# Report\Clusterd\clinicaltrials\queris\True
# ---------------------------
# ---------------------------
# Report\Clusterd\clinicaltrials\queris\False
# ---------------------------
# Directory created: Report\Clusterd\clinicaltrials\queris\text\a
# Directory created: Report\Clusterd\clinicaltrials\queris\text\b
# Directory created: Report\Clusterd\clinicaltrials\queris\text\c
# Directory created: Report\Clusterd\clinicaltrials\queris\text\d
# Directory created: Report\Clusterd\clinicaltrials\queris\text\e
# Directory created: Report\Clusterd\clinicaltrials\queris\text\f
# Directory created: Report\Clusterd\clinicaltrials\queris\text\g
# Directory created: Report\Clusterd\clinicaltrials\queris\text\h
# Directory created: Report\Clusterd\clinicaltrials\queris\text\i
# Directory created: Report\Clusterd\clinicaltrials\queris\text\j
# Directory created: Report\Clusterd\clinicaltrials\queris\text\k
# Directory created: Report\Clusterd\clinicaltrials\queris\text\l
# Directory created: Report\Clusterd\clinicaltrials\queris\text\m
# Directory created: Report\Clusterd\clinicaltrials\queris\text\n
# Directory created: Report\Clusterd\clinicaltrials\queris\text\o
# Directory created: Report\Clusterd\clinicaltrials\queris\text\p
# Directory created: Report\Clusterd\clinicaltrials\queris\text\q
# Directory created: Report\Clusterd\clinicaltrials\queris\text\r
# Directory created: Report\Clusterd\clinicaltrials\queris\text\s
# Directory created: Report\Clusterd\clinicaltrials\queris\text\t
# Directory created: Report\Clusterd\clinicaltrials\queris\text\u
# Directory created: Report\Clusterd\clinicaltrials\queris\text\v
# Directory created: Report\Clusterd\clinicaltrials\queris\text\w
# Directory created: Report\Clusterd\clinicaltrials\queris\text\x
# Directory created: Report\Clusterd\clinicaltrials\queris\text\y
# Directory created: Report\Clusterd\clinicaltrials\queris\text\z
# ---------------------------
# Report\Clusterd\clinicaltrials\documents\True
# ---------------------------
# ---------------------------
# Report\Clusterd\clinicaltrials\documents\False
# ---------------------------
# Directory created: Report\Clusterd\clinicaltrials\documents\title\a
# Directory created: Report\Clusterd\clinicaltrials\documents\title\b
# Directory created: Report\Clusterd\clinicaltrials\documents\title\c
# Directory created: Report\Clusterd\clinicaltrials\documents\title\d
# Directory created: Report\Clusterd\clinicaltrials\documents\title\e
# Directory created: Report\Clusterd\clinicaltrials\documents\title\f
# Directory created: Report\Clusterd\clinicaltrials\documents\title\g
# Directory created: Report\Clusterd\clinicaltrials\documents\title\h
# Directory created: Report\Clusterd\clinicaltrials\documents\title\i
# Directory created: Report\Clusterd\clinicaltrials\documents\title\j
# Directory created: Report\Clusterd\clinicaltrials\documents\title\k
# Directory created: Report\Clusterd\clinicaltrials\documents\title\l
# Directory created: Report\Clusterd\clinicaltrials\documents\title\m
# Directory created: Report\Clusterd\clinicaltrials\documents\title\n
# Directory created: Report\Clusterd\clinicaltrials\documents\title\o
# Directory created: Report\Clusterd\clinicaltrials\documents\title\p
# Directory created: Report\Clusterd\clinicaltrials\documents\title\q
# Directory created: Report\Clusterd\clinicaltrials\documents\title\r
# Directory created: Report\Clusterd\clinicaltrials\documents\title\s
# Directory created: Report\Clusterd\clinicaltrials\documents\title\t
# Directory created: Report\Clusterd\clinicaltrials\documents\title\u
# Directory created: Report\Clusterd\clinicaltrials\documents\title\v
# Directory created: Report\Clusterd\clinicaltrials\documents\title\w
# Directory created: Report\Clusterd\clinicaltrials\documents\title\x
# Directory created: Report\Clusterd\clinicaltrials\documents\title\y
# Directory created: Report\Clusterd\clinicaltrials\documents\title\z
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\a
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\b
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\c
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\d
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\e
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\f
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\g
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\h
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\i
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\j
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\k
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\l
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\m
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\n
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\o
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\p
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\q
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\r
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\s
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\t
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\u
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\v
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\w
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\x
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\y
# Directory created: Report\Clusterd\clinicaltrials\documents\condition\z
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\a
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\b
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\c
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\d
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\e
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\f
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\g
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\h
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\i
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\j
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\k
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\l
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\m
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\n
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\o
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\p
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\q
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\r
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\s
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\t
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\u
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\v
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\w
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\x
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\y
# Directory created: Report\Clusterd\clinicaltrials\documents\summary\z
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\a
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\b
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\c
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\d
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\e
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\f
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\g
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\h
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\i
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\j
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\k
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\l
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\m
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\n
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\o
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\p
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\q
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\r
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\s
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\t
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\u
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\v
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\w
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\x
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\y
# Directory created: Report\Clusterd\clinicaltrials\documents\detailed_description\z
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\a
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\b
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\c
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\d
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\e
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\f
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\g
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\h
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\i
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\j
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\k
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\l
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\m
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\n
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\o
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\p
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\q
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\r
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\s
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\t
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\u
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\v
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\w
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\x
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\y
# Directory created: Report\Clusterd\clinicaltrials\documents\eligibility\z

# %%
create_clustersd(doc_and_qry_and_qrl, clusterd_ٍspecial_path, antiqueDataset, name_antique)
create_clustersd(doc_and_qry_and_qrl, clusterd_ٍspecial_path, clinicaltrials_2021, name_clinicaltrials)
# Out:
# ---------------------------
# Report\Clusterd Special\antique\queris\True
# ---------------------------
# ---------------------------
# Report\Clusterd Special\antique\queris\False
# ---------------------------
# Directory created: Report\Clusterd Special\antique\queris\text\a
# Directory created: Report\Clusterd Special\antique\queris\text\b
# Directory created: Report\Clusterd Special\antique\queris\text\c
# Directory created: Report\Clusterd Special\antique\queris\text\d
# Directory created: Report\Clusterd Special\antique\queris\text\e
# Directory created: Report\Clusterd Special\antique\queris\text\f
# Directory created: Report\Clusterd Special\antique\queris\text\g
# Directory created: Report\Clusterd Special\antique\queris\text\h
# Directory created: Report\Clusterd Special\antique\queris\text\i
# Directory created: Report\Clusterd Special\antique\queris\text\j
# Directory created: Report\Clusterd Special\antique\queris\text\k
# Directory created: Report\Clusterd Special\antique\queris\text\l
# Directory created: Report\Clusterd Special\antique\queris\text\m
# Directory created: Report\Clusterd Special\antique\queris\text\n
# Directory created: Report\Clusterd Special\antique\queris\text\o
# Directory created: Report\Clusterd Special\antique\queris\text\p
# Directory created: Report\Clusterd Special\antique\queris\text\q
# Directory created: Report\Clusterd Special\antique\queris\text\r
# Directory created: Report\Clusterd Special\antique\queris\text\s
# Directory created: Report\Clusterd Special\antique\queris\text\t
# Directory created: Report\Clusterd Special\antique\queris\text\u
# Directory created: Report\Clusterd Special\antique\queris\text\v
# Directory created: Report\Clusterd Special\antique\queris\text\w
# Directory created: Report\Clusterd Special\antique\queris\text\x
# Directory created: Report\Clusterd Special\antique\queris\text\y
# Directory created: Report\Clusterd Special\antique\queris\text\z
# ---------------------------
# Report\Clusterd Special\antique\qrels\True
# ---------------------------
# ---------------------------
# Report\Clusterd Special\antique\qrels\False
# ---------------------------
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\a
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\b
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\c
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\d
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\e
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\f
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\g
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\h
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\i
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\j
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\k
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\l
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\m
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\n
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\o
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\p
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\q
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\r
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\s
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\t
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\u
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\v
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\w
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\x
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\y
# Directory created: Report\Clusterd Special\antique\qrels\doc_id\z
# Directory created: Report\Clusterd Special\antique\qrels\relevance\a
# Directory created: Report\Clusterd Special\antique\qrels\relevance\b
# Directory created: Report\Clusterd Special\antique\qrels\relevance\c
# Directory created: Report\Clusterd Special\antique\qrels\relevance\d
# Directory created: Report\Clusterd Special\antique\qrels\relevance\e
# Directory created: Report\Clusterd Special\antique\qrels\relevance\f
# Directory created: Report\Clusterd Special\antique\qrels\relevance\g
# Directory created: Report\Clusterd Special\antique\qrels\relevance\h
# Directory created: Report\Clusterd Special\antique\qrels\relevance\i
# Directory created: Report\Clusterd Special\antique\qrels\relevance\j
# Directory created: Report\Clusterd Special\antique\qrels\relevance\k
# Directory created: Report\Clusterd Special\antique\qrels\relevance\l
# Directory created: Report\Clusterd Special\antique\qrels\relevance\m
# Directory created: Report\Clusterd Special\antique\qrels\relevance\n
# Directory created: Report\Clusterd Special\antique\qrels\relevance\o
# Directory created: Report\Clusterd Special\antique\qrels\relevance\p
# Directory created: Report\Clusterd Special\antique\qrels\relevance\q
# Directory created: Report\Clusterd Special\antique\qrels\relevance\r
# Directory created: Report\Clusterd Special\antique\qrels\relevance\s
# Directory created: Report\Clusterd Special\antique\qrels\relevance\t
# Directory created: Report\Clusterd Special\antique\qrels\relevance\u
# Directory created: Report\Clusterd Special\antique\qrels\relevance\v
# Directory created: Report\Clusterd Special\antique\qrels\relevance\w
# Directory created: Report\Clusterd Special\antique\qrels\relevance\x
# Directory created: Report\Clusterd Special\antique\qrels\relevance\y
# Directory created: Report\Clusterd Special\antique\qrels\relevance\z
# Directory created: Report\Clusterd Special\antique\qrels\iteration\a
# Directory created: Report\Clusterd Special\antique\qrels\iteration\b
# Directory created: Report\Clusterd Special\antique\qrels\iteration\c
# Directory created: Report\Clusterd Special\antique\qrels\iteration\d
# Directory created: Report\Clusterd Special\antique\qrels\iteration\e
# Directory created: Report\Clusterd Special\antique\qrels\iteration\f
# Directory created: Report\Clusterd Special\antique\qrels\iteration\g
# Directory created: Report\Clusterd Special\antique\qrels\iteration\h
# Directory created: Report\Clusterd Special\antique\qrels\iteration\i
# Directory created: Report\Clusterd Special\antique\qrels\iteration\j
# Directory created: Report\Clusterd Special\antique\qrels\iteration\k
# Directory created: Report\Clusterd Special\antique\qrels\iteration\l
# Directory created: Report\Clusterd Special\antique\qrels\iteration\m
# Directory created: Report\Clusterd Special\antique\qrels\iteration\n
# Directory created: Report\Clusterd Special\antique\qrels\iteration\o
# Directory created: Report\Clusterd Special\antique\qrels\iteration\p
# Directory created: Report\Clusterd Special\antique\qrels\iteration\q
# Directory created: Report\Clusterd Special\antique\qrels\iteration\r
# Directory created: Report\Clusterd Special\antique\qrels\iteration\s
# Directory created: Report\Clusterd Special\antique\qrels\iteration\t
# Directory created: Report\Clusterd Special\antique\qrels\iteration\u
# Directory created: Report\Clusterd Special\antique\qrels\iteration\v
# Directory created: Report\Clusterd Special\antique\qrels\iteration\w
# Directory created: Report\Clusterd Special\antique\qrels\iteration\x
# Directory created: Report\Clusterd Special\antique\qrels\iteration\y
# Directory created: Report\Clusterd Special\antique\qrels\iteration\z
# ---------------------------
# Report\Clusterd Special\antique\documents\True
# ---------------------------
# ---------------------------
# Report\Clusterd Special\antique\documents\False
# ---------------------------
# Directory created: Report\Clusterd Special\antique\documents\text\a
# Directory created: Report\Clusterd Special\antique\documents\text\b
# Directory created: Report\Clusterd Special\antique\documents\text\c
# Directory created: Report\Clusterd Special\antique\documents\text\d
# Directory created: Report\Clusterd Special\antique\documents\text\e
# Directory created: Report\Clusterd Special\antique\documents\text\f
# Directory created: Report\Clusterd Special\antique\documents\text\g
# Directory created: Report\Clusterd Special\antique\documents\text\h
# Directory created: Report\Clusterd Special\antique\documents\text\i
# Directory created: Report\Clusterd Special\antique\documents\text\j
# Directory created: Report\Clusterd Special\antique\documents\text\k
# Directory created: Report\Clusterd Special\antique\documents\text\l
# Directory created: Report\Clusterd Special\antique\documents\text\m
# Directory created: Report\Clusterd Special\antique\documents\text\n
# Directory created: Report\Clusterd Special\antique\documents\text\o
# Directory created: Report\Clusterd Special\antique\documents\text\p
# Directory created: Report\Clusterd Special\antique\documents\text\q
# Directory created: Report\Clusterd Special\antique\documents\text\r
# Directory created: Report\Clusterd Special\antique\documents\text\s
# Directory created: Report\Clusterd Special\antique\documents\text\t
# Directory created: Report\Clusterd Special\antique\documents\text\u
# Directory created: Report\Clusterd Special\antique\documents\text\v
# Directory created: Report\Clusterd Special\antique\documents\text\w
# Directory created: Report\Clusterd Special\antique\documents\text\x
# Directory created: Report\Clusterd Special\antique\documents\text\y
# Directory created: Report\Clusterd Special\antique\documents\text\z
# ---------------------------
# Report\Clusterd Special\clinicaltrials\queris\True
# ---------------------------
# ---------------------------
# Report\Clusterd Special\clinicaltrials\queris\False
# ---------------------------
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\a
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\b
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\c
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\d
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\e
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\f
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\g
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\h
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\i
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\j
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\k
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\l
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\m
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\n
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\o
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\p
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\q
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\r
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\s
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\t
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\u
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\v
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\w
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\x
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\y
# Directory created: Report\Clusterd Special\clinicaltrials\queris\text\z
# ---------------------------
# Report\Clusterd Special\clinicaltrials\qrels\True
# ---------------------------
# ---------------------------
# Report\Clusterd Special\clinicaltrials\qrels\False
# ---------------------------
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\a
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\b
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\c
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\d
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\e
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\f
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\g
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\h
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\i
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\j
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\k
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\l
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\m
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\n
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\o
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\p
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\q
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\r
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\s
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\t
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\u
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\v
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\w
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\x
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\y
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\doc_id\z
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\a
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\b
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\c
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\d
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\e
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\f
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\g
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\h
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\i
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\j
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\k
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\l
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\m
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\n
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\o
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\p
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\q
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\r
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\s
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\t
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\u
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\v
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\w
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\x
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\y
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\relevance\z
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\a
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\b
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\c
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\d
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\e
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\f
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\g
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\h
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\i
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\j
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\k
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\l
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\m
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\n
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\o
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\p
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\q
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\r
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\s
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\t
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\u
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\v
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\w
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\x
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\y
# Directory created: Report\Clusterd Special\clinicaltrials\qrels\iteration\z
# ---------------------------
# Report\Clusterd Special\clinicaltrials\documents\True
# ---------------------------
# ---------------------------
# Report\Clusterd Special\clinicaltrials\documents\False
# ---------------------------
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\a
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\b
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\c
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\d
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\e
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\f
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\g
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\h
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\i
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\j
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\k
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\l
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\m
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\n
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\o
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\p
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\q
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\r
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\s
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\t
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\u
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\v
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\w
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\x
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\y
# Directory created: Report\Clusterd Special\clinicaltrials\documents\title\z
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\a
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\b
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\c
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\d
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\e
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\f
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\g
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\h
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\i
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\j
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\k
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\l
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\m
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\n
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\o
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\p
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\q
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\r
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\s
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\t
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\u
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\v
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\w
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\x
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\y
# Directory created: Report\Clusterd Special\clinicaltrials\documents\condition\z
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\a
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\b
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\c
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\d
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\e
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\f
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\g
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\h
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\i
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\j
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\k
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\l
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\m
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\n
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\o
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\p
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\q
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\r
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\s
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\t
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\u
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\v
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\w
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\x
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\y
# Directory created: Report\Clusterd Special\clinicaltrials\documents\summary\z
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\a
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\b
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\c
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\d
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\e
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\f
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\g
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\h
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\i
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\j
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\k
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\l
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\m
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\n
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\o
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\p
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\q
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\r
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\s
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\t
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\u
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\v
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\w
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\x
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\y
# Directory created: Report\Clusterd Special\clinicaltrials\documents\detailed_description\z
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\a
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\b
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\c
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\d
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\e
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\f
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\g
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\h
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\i
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\j
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\k
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\l
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\m
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\n
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\o
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\p
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\q
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\r
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\s
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\t
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\u
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\v
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\w
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\x
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\y
# Directory created: Report\Clusterd Special\clinicaltrials\documents\eligibility\z

# %%
import nltk
from nltk.tokenize import word_tokenize , sent_tokenize
import os
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk import pos_tag
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
def clean_text(text):
    letters_only = re.sub("[^a-zA-Z]", " ", str(text))
    return letters_only

# %%
def lower_text(text):
     # Convert the content to lowercase
    lowercase_text = text.lower()
    return lowercase_text

# %%
def tokenize(text):
    # Tokenize the text
    words = word_tokenize(text)
    # Stemming
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in words]
    return stemmed_words
text = 'Content Filtereng: During crowling and or the, filter downloaded content to keep only relevant parts. This could involve looking for specific keywords, document types (e.g., HTML, PDF), or URLs matching a pattern.'
print(tokenize(lower_text(clean_text(text))))
# Out:
# ['content', 'filtereng', 'dure', 'crowl', 'and', 'or', 'the', 'filter', 'download', 'content', 'to', 'keep', 'onli', 'relev', 'part', 'thi', 'could', 'involv', 'look', 'for', 'specif', 'keyword', 'document', 'type', 'e', 'g', 'html', 'pdf', 'or', 'url', 'match', 'a', 'pattern']

# %%
import os
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Get English stopwords
stopwords_english = set(stopwords.words('english'))

def removeStopWords(words):
    # Remove stopwords
    filtered_words = [word for word in words if word.lower() not in stopwords_english]
    # Join the filtered words back into a string
    #filtered_text = ' '.join(filtered_words)
    return filtered_words
text = 'Content Filtereng: During crowling and or the, filter downloaded content to keep only relevant parts. This could involve looking for specific keywords, document types (e.g., HTML, PDF), or URLs matching a pattern.'

print(removeStopWords(tokenize(lower_text(clean_text(text)))))
# Out:
# ['content', 'filtereng', 'dure', 'crowl', 'filter', 'download', 'content', 'keep', 'onli', 'relev', 'part', 'thi', 'could', 'involv', 'look', 'specif', 'keyword', 'document', 'type', 'e', 'g', 'html', 'pdf', 'url', 'match', 'pattern']

# %%
import os
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import wordnet

def get_wordnet_pos(tag_parameter):
    tag = tag_parameter[0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)


def lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    pos_tags = pos_tag(text)
    lemmatized_words = [lemmatizer.lemmatize(word, pos=get_wordnet_pos(tag)) for word, tag in pos_tags]
    return lemmatized_words

# %%
def editing(text):
    token = removeStopWords(tokenize(lower_text(clean_text(text))))
    lem = lemmatize(token)
    #print("token: "+str(token))
    #print("lem: "+str(lem))
    return lem
text = 'Content Filtereng: During crowling and or the, filter downloaded content to keep only relevant parts. This could involve looking for specific keywords, document types (e.g., HTML, PDF), or URLs matching a pattern.'
editing(text)
# Out:
# ['content',
#  'filtereng',
#  'dure',
#  'crowl',
#  'filter',
#  'download',
#  'content',
#  'keep',
#  'onli',
#  'relev',
#  'part',
#  'thi',
#  'could',
#  'involv',
#  'look',
#  'specif',
#  'keyword',
#  'document',
#  'type',
#  'e',
#  'g',
#  'html',
#  'pdf',
#  'url',
#  'match',
#  'pattern']

# %%
from spellchecker import SpellChecker
import os
from nltk.tokenize import word_tokenize
from typing import List
from spellchecker import SpellChecker


def correct_sentence_spelling(tokens: List[str]) -> List[str]:
    correct_list = []
    spell = SpellChecker()
    misspelled = spell.unknown(tokens)
    for i, token in enumerate(tokens):
        if len(token) > 1:
            if token in misspelled:
                corrected = spell.correction(token)
                if corrected is not None:
                    tokens[i] = corrected
            correct_list.append(tokens[i])
    return correct_list

list_text = correct_sentence_spelling(removeStopWords(lower_text(clean_text(text))))
for li in list_text:
    le = lemmatize(li)
    print(str(li[0]) +" : "+ str(le[0]))

# %%
import pandas as pd
import math
from nltk.tokenize import word_tokenize
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def indexing(json_object):
    indexing_terms = set()
    for doc in json_object.values():
        #print(doc)
        if doc is None:
            continue
        indexing_terms.update(word_tokenize(doc))

    indexing_terms_df = pd.DataFrame(indexing_terms)
    #indexing_terms_df
    for i in indexing_terms_df[0]:
        print(str(i))

# %%
def invert_index(json_object):
    inverted_index = defaultdict(list)

    for docId, doc in json_object.items():
        if doc is None:
            continue
        doc_terms = set(word_tokenize(doc))
        for term in doc_terms:
            inverted_index[term].append(docId)

    dict(inverted_index)
    return inverted_index
    
    #print(inverted_index)

# %% [markdown]
# # Calculating

# %%
def calculate_tf(doc:str):
    tf = {}
    doc_terms = word_tokenize(doc)
    for term in doc_terms:
        tf[term] = (doc_terms.count(term) / len(doc_terms)) 
    #print(tf)
    return tf

# %%
def calculate_idf(inverted_index, chunksize):
    idf = {}
    for term, doc_ids in inverted_index.items():
        idf[term] = math.log((chunksize / len(doc_ids)) + 1)
    #print(idf)
    return idf

# %%
def calculate(json_data, inverted_index, chunksize):
    count = 0
    sum_ = 0.0
    
    tf_idf = {}
    for text in json_data.values():
        if text is not None:
            doc_terms = word_tokenize(text)
            doc_tf = calculate_tf(text)
            idf = calculate_idf(inverted_index, chunksize)
            for term in doc_terms:
                tf_idf[term] = doc_tf[term] * idf[term]
                sum_ = sum_ + tf_idf[term]  
        count += 1
        if (count%1000) == 1:
            print("counter: "+ str(count))
    #print(tf_idf)
    return tf_idf, count, sum_

# %% [markdown]
# # Add words to clustered

# %%
def transport_xml_files_to_clusterd_pro(doc_and_qry_and_qrl, path_base, Dataset, path_clustered, clusterd_ٍspecial_path, name, level, chunksize, special_value):
    old_level = level -1
    path1 = path_base + str(old_level)+"\\"+name
    print("level: "+str(level))
    for doc_or_qry_or_qrl in doc_and_qry_and_qrl:
        part = 1
        part_0 = 1
        count = 1
        print("doc_or_qry_or_qrl: "+str(doc_or_qry_or_qrl))
        if doc_or_qry_or_qrl == "qrel":
            Dataset_Count = Dataset.qrels_count()
            path2 = path1 +"\\qrels\\"+name
            path_clustered2 = path_clustered +name+"\\qrels\\"
            clusterd_ٍspecial_path2 = clusterd_ٍspecial_path +name+"\\qrels\\"
            collection = Dataset.qrels_iter()
            items = Dataset.qrels_cls()._fields
            
        elif doc_or_qry_or_qrl == "query":
            Dataset_Count = Dataset.queries_count()
            path2 = path1 +"\\queris\\"+name
            path_clustered2 = path_clustered +name+"\\queris\\"
            clusterd_ٍspecial_path2 = clusterd_ٍspecial_path +name+"\\queris\\"
            collection = Dataset.queries_iter()
            items = Dataset.queries_cls()._fields
        else:
            Dataset_Count = Dataset.docs_count()
            path2 = path1 +"\\documents\\"+name
            path_clustered2 = path_clustered +name+"\\documents\\"
            clusterd_ٍspecial_path2 = clusterd_ٍspecial_path +name+"\\documents\\"
            collection = Dataset.docs_iter()
            items = Dataset.docs_cls()._fields 
    
        countAll = 0
        sumAll = 0.0
        
        
        while part < (Dataset_Count / chunksize + 1):
            path3 = path2 + str(part) + ".xml"
            print("path3:  "+path3)
            is_id = True
            for tag in items:
                if is_id:
                    is_id = False
                    continue
                path_clustered3 = path_clustered2 + tag + "\\"
                clusterd_ٍspecial_path3 = clusterd_ٍspecial_path2 + tag + "\\"
                json_data = xml_to_json(path3, doc_or_qry_or_qrl, tag, items[0])
                inverted_index = invert_index(json_data)
                print("to json")
                tf_idf_list, count, sum_ = calculate(json_data, inverted_index, chunksize)
                print("calc")
                countAll += count
                sumAll = sumAll + sum_
                for word, lista in inverted_index.items():
                    if tf_idf_list[word] >= special_value:
                        add_word_to_clusterd(word, clusterd_ٍspecial_path3, lista, tf_idf_list[word])
                    else:
                        add_word_to_clusterd(word, path_clustered3, lista, tf_idf_list[word])
            
            print("part "+str(part)+ "  is Done..")
            part = part + 1
        print(sumAll / countAll)

# %%
def add_word_to_clusterd(word, path, id_list , num):
    if len(word) > 1:
        file_path = path + str(word[0]) + "\\" + str(word[1]) + ".xml"
        print("add "+ word + " file_path:  " + file_path + "( " +str(num)+ ")")
        tree = ET.parse(file_path)
        root = tree.getroot()
        word_element = root.find(word)
        if word_element is not None:
            for id_ in id_list:
                id_subelement = ET.SubElement(word_element, "id")
                id_subelement.text = id_
                #print("element_id:  " + str(element_id))
        else:
            # If the "word" element doesn't exist, add it and the "id" subelement
            word_element = ET.SubElement(root, word)
            for id_ in id_list:
                id_subelement = ET.SubElement(word_element, "id")
                id_subelement.text = id_
                #print("element_id:  " + str(element_id))
        #print("-----------------------")
        tree = ET.ElementTree(root)
        tree.write(file_path)

# %%
import json
import xml.etree.ElementTree as ET


def xml_to_json(xml_file, d_q_q, tag, id_tag):
    try:
        tree = ET.parse(xml_file)
        root = tree.getroot()

        json_data = {}
        for element in root.findall(d_q_q):
            tagElement = element.find(tag)
            id_element = element.find(id_tag)
            if tagElement is None:
                raise ValueError("Missing element in an element")
            text = tagElement.text
            id_text = id_element.text
            json_data[id_text] = text
        return json_data

    except FileNotFoundError:
        print(f"Error: XML file '{xml_file}' not found.")
        return {}
    except ValueError as e:
        print(f"Error: {e}")
        return {}

# %%
special_value = 2.5
transport_xml_files_to_clusterd_pro(doc_and_qry_and_qrl_, path_antique, antiqueDataset, clusterd_path, clusterd_ٍspecial_path, name_antique, 4, chunksize, special_value)
# Out:
# level: 4
# doc_or_qry_or_qrl: document
# path3:  Report\newDataset\part 3\antique\documents\antique1.xml
# to json
# counter: 1
# counter: 1001
# counter: 2001
# counter: 3001
# counter: 4001
# counter: 5001
# counter: 6001
# counter: 7001
# counter: 8001
# counter: 9001
# counter: 10001
# counter: 11001
# counter: 12001
# counter: 13001
# counter: 14001
# counter: 15001
# counter: 16001
# counter: 17001
# counter: 18001
# counter: 19001
# counter: 20001
# counter: 21001
# counter: 22001
# counter: 23001
# counter: 24001
# counter: 25001
# counter: 26001
# counter: 27001
# counter: 28001
# counter: 29001
# counter: 30001
# counter: 31001
# counter: 32001
# counter: 33001
# counter: 34001
# counter: 35001
# counter: 36001
# counter: 37001
# counter: 38001
# counter: 39001
# counter: 40001
# counter: 41001
# counter: 42001
# counter: 43001
# counter: 44001
# counter: 45001
# counter: 46001
# counter: 47001
# counter: 48001
# counter: 49001
# counter: 50001
# counter: 51001
# counter: 52001
# counter: 53001
# counter: 54001
# counter: 55001
# counter: 56001
# counter: 57001
# counter: 58001
# counter: 59001
# counter: 60001
# counter: 61001
# counter: 62001
# counter: 63001
# counter: 64001
# counter: 65001
# counter: 66001
# counter: 67001
# counter: 68001
# counter: 69001
# counter: 70001
# counter: 71001
# counter: 72001
# counter: 73001
# counter: 74001
# counter: 75001
# counter: 76001
# counter: 77001
# counter: 78001
# counter: 79001
# counter: 80001
# counter: 81001
# counter: 82001
# counter: 83001
# counter: 84001
# counter: 85001
# counter: 86001
# counter: 87001
# counter: 88001
# counter: 89001
# counter: 90001
# counter: 91001
# counter: 92001
# counter: 93001
# counter: 94001
# counter: 95001
# counter: 96001
# counter: 97001
# counter: 98001
# counter: 99001
# counter: 100001
# counter: 101001
# counter: 102001
# counter: 103001
# counter: 104001
# counter: 105001
# counter: 106001
# counter: 107001
# counter: 108001
# counter: 109001
# counter: 110001
# counter: 111001
# counter: 112001
# counter: 113001
# counter: 114001
# counter: 115001
# counter: 116001
# counter: 117001
# counter: 118001
# counter: 119001
# counter: 120001
# counter: 121001
# counter: 122001
# counter: 123001
# counter: 124001
# counter: 125001
# counter: 126001
# counter: 127001
# counter: 128001
# counter: 129001
# counter: 130001
# counter: 131001
# counter: 132001
# counter: 133001
# counter: 134001
# counter: 135001
# counter: 136001
# counter: 137001
# counter: 138001
# counter: 139001
# counter: 140001
# counter: 141001
# counter: 142001
# counter: 143001
# counter: 144001
# counter: 145001
# counter: 146001
# counter: 147001
# counter: 148001
# counter: 149001
# counter: 150001
# counter: 151001
# counter: 152001
# counter: 153001
# counter: 154001
# counter: 155001
# counter: 156001
# counter: 157001
# counter: 158001
# counter: 159001
# counter: 160001
# counter: 161001
# counter: 162001
# counter: 163001
# counter: 164001
# counter: 165001
# counter: 166001
# counter: 167001
# counter: 168001
# counter: 169001
# counter: 170001
# counter: 171001
# counter: 172001
# counter: 173001
# counter: 174001
# counter: 175001
# counter: 176001
# counter: 177001
# counter: 178001
# counter: 179001
# counter: 180001
# counter: 181001
# counter: 182001
# counter: 183001
# counter: 184001
# counter: 185001
# counter: 186001
# counter: 187001
# counter: 188001
# counter: 189001
# counter: 190001
# counter: 191001
# counter: 192001
# counter: 193001
# counter: 194001
# counter: 195001
# counter: 196001
# counter: 197001
# counter: 198001
# counter: 199001
# counter: 200001
# calc
# add becaus file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.052050424165906696)
# add oil file_path:  Report\Clusterd\antique\documents\text\o\i.xml( 0.621279707417781)
# add iraq file_path:  Report\Clusterd\antique\documents\text\i\r.xml( 0.731822308184786)
# add lot file_path:  Report\Clusterd\antique\documents\text\l\o.xml( 0.13313414954302014)
# add world file_path:  Report\Clusterd\antique\documents\text\w\o.xml( 0.05546735190137467)
# add occupi file_path:  Report\Clusterd\antique\documents\text\o\c.xml( 0.17577031292852946)
# add next file_path:  Report\Clusterd\antique\documents\text\n\e.xml( 0.049110769715818056)
# add result file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.08895340415342275)
# add assumpt file_path:  Report\Clusterd\antique\documents\text\a\s.xml( 0.019522164199571947)
# add regim file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.029218386888193146)
# add democrat file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.0715282133228267)
# add believ file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.7164424418201438)
# add countri file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.11194604908604011)
# add line file_path:  Report\Clusterd\antique\documents\text\l\i.xml( 0.21731128919848852)
# add one file_path:  Report\Clusterd\antique\documents\text\o\n.xml( 0.06377450500070575)
# add fall file_path:  Report\Clusterd\antique\documents\text\f\a.xml( 0.30660232122172787)
# add influenc file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.14678534769579757)
# add invad file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 1.68585628473656)
# add exactli file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.14179130552318933)
# add huge file_path:  Report\Clusterd\antique\documents\text\h\u.xml( 0.0825440379194728)
# add wa file_path:  Report\Clusterd\antique\documents\text\w\a.xml( 0.2944752274738612)
# add defeat file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.056852597020389035)
# add start file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.23802621027550774)
# add deter file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.42694910720026463)
# add penetr file_path:  Report\Clusterd\antique\documents\text\p\e.xml( 0.07462208500428662)
# add first file_path:  Report\Clusterd\antique\documents\text\f\i.xml( 0.16584488797582497)
# add fanat file_path:  Report\Clusterd\antique\documents\text\f\a.xml( 0.3634215022388568)
# add presumptu file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.48166657875664015)
# add wide file_path:  Report\Clusterd\antique\documents\text\w\i.xml( 0.015463677184684879)
# add whi file_path:  Report\Clusterd\antique\documents\text\w\h.xml( 0.12331611874944336)
# add maintain file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.03170382696682348)
# add problem file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.31112424604903466)
# add conclus file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.16962826236532302)
# add tempt file_path:  Report\Clusterd\antique\documents\text\t\e.xml( 0.2366207350671059)
# add thi file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 0.04972014092016932)
# add enemi file_path:  Report\Clusterd\antique\documents\text\e\n.xml( 0.05041864439572907)
# add power file_path:  Report\Clusterd\antique\documents\text\p\o.xml( 0.05359879203030357)
# add side file_path:  Report\Clusterd\antique\documents\text\s\i.xml( 0.7063105994592297)
# add way file_path:  Report\Clusterd\antique\documents\text\w\a.xml( 0.10350962615873553)
# add understand file_path:  Report\Clusterd\antique\documents\text\u\n.xml( 0.11562264252316692)
# add time file_path:  Report\Clusterd\antique\documents\text\t\i.xml( 0.09070262190717465)
# add surviv file_path:  Report\Clusterd\antique\documents\text\s\u.xml( 0.7210326481740907)
# add like file_path:  Report\Clusterd\antique\documents\text\l\i.xml( 0.05051915597727168)
# add easi file_path:  Report\Clusterd\antique\documents\text\e\a.xml( 0.3806477638648088)
# add spread file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.16824103073862937)
# add reason file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.1639781109510215)
# add common file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.7169546605628441)
# add cabl file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.13047010845101362)
# add rais file_path:  Report\Clusterd\antique\documents\text\r\a.xml( 0.3026496625443221)
# add week file_path:  Report\Clusterd\antique\documents\text\w\e.xml( 0.08077369725660133)
# add war file_path:  Report\Clusterd\antique\documents\text\w\a.xml( 0.30728018663523793)
# add afghanistan file_path:  Report\Clusterd\antique\documents\text\a\f.xml( 0.39444822299060744)
# add religion file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.16208922423786395)
# add scenario file_path:  Report\Clusterd\antique\documents\text\s\c.xml( 0.27296493572236763)
# add would file_path:  Report\Clusterd\antique\documents\text\w\o.xml( 0.21192176416164088)
# add say file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.09637212758965301)
# add counti file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.3645204931152879)
# add govern file_path:  Report\Clusterd\antique\documents\text\g\o.xml( 0.35776302836670304)
# add syria file_path:  Report\Clusterd\antique\documents\text\s\y.xml( 0.04695636320663046)
# add come file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.21095646481107555)
# add fear file_path:  Report\Clusterd\antique\documents\text\f\e.xml( 0.33962162782606053)
# add toward file_path:  Report\Clusterd\antique\documents\text\t\o.xml( 0.07918361097899992)
# add econom file_path:  Report\Clusterd\antique\documents\text\e\c.xml( 0.05104495541972786)
# add form file_path:  Report\Clusterd\antique\documents\text\f\o.xml( 0.37100439732005114)
# add actual file_path:  Report\Clusterd\antique\documents\text\a\c.xml( 0.08823124439287135)
# add ideolog file_path:  Report\Clusterd\antique\documents\text\i\d.xml( 0.4802968100251335)
# add man file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.11449884311002043)
# add satellit file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.535507306248311)
# add gain file_path:  Report\Clusterd\antique\documents\text\g\a.xml( 0.542041553804229)
# add caus file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.07640685368686097)
# add extrem file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.043333822447212775)
# add fight file_path:  Report\Clusterd\antique\documents\text\f\i.xml( 0.07598501615160225)
# add hatr file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.12354677692339766)
# add outsid file_path:  Report\Clusterd\antique\documents\text\o\u.xml( 0.37269276359833714)
# add tri file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.032189672126680606)
# add ha file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.030594351552718325)
# add direct file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.27132911084786004)
# add alreadi file_path:  Report\Clusterd\antique\documents\text\a\l.xml( 0.0693326507829046)
# add need file_path:  Report\Clusterd\antique\documents\text\n\e.xml( 0.4808982618915848)
# add deep file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.19240628483958191)
# add mani file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.15620770702034145)
# add captur file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.16950101971193218)
# add etc file_path:  Report\Clusterd\antique\documents\text\e\t.xml( 0.10310422323515549)
# add even file_path:  Report\Clusterd\antique\documents\text\e\v.xml( 0.08952848870758046)
# add best file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.23718174559295874)
# add think file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 0.028717941712825573)
# add moslem file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 0.12783015854852875)
# add internet file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.07134808533853616)
# add keep file_path:  Report\Clusterd\antique\documents\text\k\e.xml( 0.12868827117158674)
# add hate file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.27376886560966035)
# add verg file_path:  Report\Clusterd\antique\documents\text\v\e.xml( 0.36326805077525465)
# add medium file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.24512757457152742)
# add kuwait file_path:  Report\Clusterd\antique\documents\text\k\u.xml( 0.04094902966541639)
# add push file_path:  Report\Clusterd\antique\documents\text\p\u.xml( 0.043446580447647536)
# add secular file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.1746090287216633)
# add middl file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.2499123198457276)
# add rise file_path:  Report\Clusterd\antique\documents\text\r\i.xml( 0.15763548725695212)
# add dictatorship file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.4420863225954689)
# add year file_path:  Report\Clusterd\antique\documents\text\y\e.xml( 0.1989363310826379)
# add take file_path:  Report\Clusterd\antique\documents\text\t\a.xml( 0.04024506386892118)
# add terror file_path:  Report\Clusterd\antique\documents\text\t\e.xml( 0.34372540901033233)
# add hi file_path:  Report\Clusterd\antique\documents\text\h\i.xml( 0.1469299837670643)
# add model file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 0.21638936879350731)
# add focal file_path:  Report\Clusterd\antique\documents\text\f\o.xml( 0.1929935834553532)
# add spot file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.07025974449036344)
# add activ file_path:  Report\Clusterd\antique\documents\text\a\c.xml( 0.10026494922624687)
# add yuval file_path:  Report\Clusterd\antique\documents\text\y\u.xml( 0.3051520661370044)
# add prove file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.18356520772197882)
# add soil file_path:  Report\Clusterd\antique\documents\text\s\o.xml( 0.5937075246542105)
# add american file_path:  Report\Clusterd\antique\documents\text\a\m.xml( 0.6115997081533008)
# add point file_path:  Report\Clusterd\antique\documents\text\p\o.xml( 0.2577173835351599)
# add pretti file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.12191792858550361)
# add pentagon file_path:  Report\Clusterd\antique\documents\text\p\e.xml( 0.4874596663875824)
# add join file_path:  Report\Clusterd\antique\documents\text\j\o.xml( 0.5668506639781433)
# add rebuild file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.8626501440684834)
# add east file_path:  Report\Clusterd\antique\documents\text\e\a.xml( 0.9865089060281532)
# add rabid file_path:  Report\Clusterd\antique\documents\text\r\a.xml( 0.28591855863616955)
# add casualti file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.02466395028531305)
# add specul file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.10557510183434021)
# add ground file_path:  Report\Clusterd\antique\documents\text\g\r.xml( 0.023953011567367077)
# add list file_path:  Report\Clusterd\antique\documents\text\l\i.xml( 0.06379906106322661)
# add saddam file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.8056622591597988)
# add hussein file_path:  Report\Clusterd\antique\documents\text\h\u.xml( 0.27096117188778174)
# add democraci file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.6960003117647308)
# add valu file_path:  Report\Clusterd\antique\documents\text\v\a.xml( 0.28866220790267644)
# add help file_path:  Report\Clusterd\antique\documents\text\h\e.xml( 0.008052890525898925)
# add charg file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.34580219025606984)
# add area file_path:  Report\Clusterd\antique\documents\text\a\r.xml( 0.7005286464514904)
# add exchang file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.05940189375995387)
# add call file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.03717104595104981)
# add remov file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.03725476667398783)
# add apiarist file_path:  Report\Clusterd\antique\documents\text\a\p.xml( 0.8718630461057267)
# add hive file_path:  Report\Clusterd\antique\documents\text\h\i.xml( 0.10778423362454592)
# add belong file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.09407809160798189)
# add abl file_path:  Report\Clusterd\antique\documents\text\a\b.xml( 0.17082814797536375)
# add bee file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.5561591259068617)
# add fashion file_path:  Report\Clusterd\antique\documents\text\f\a.xml( 0.03745385001207676)
# add leav file_path:  Report\Clusterd\antique\documents\text\l\e.xml( 0.25934005802533405)
# add wear file_path:  Report\Clusterd\antique\documents\text\w\e.xml( 0.600720399060265)
# add old file_path:  Report\Clusterd\antique\documents\text\o\l.xml( 0.39284052701786804)
# add assembl file_path:  Report\Clusterd\antique\documents\text\a\s.xml( 0.14900974767339797)
# add sack file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.19198233018927527)
# add cobol file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.19374734357905038)
# add rid file_path:  Report\Clusterd\antique\documents\text\r\i.xml( 0.14610667854544765)
# add bit file_path:  Report\Clusterd\antique\documents\text\b\i.xml( 0.22339397968981858)
# add burn file_path:  Report\Clusterd\antique\documents\text\b\u.xml( 0.10827286992113376)
# add thick file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 0.12125524289563648)
# add eye file_path:  Report\Clusterd\antique\documents\text\e\y.xml( 0.23896969008159727)
# add cloth file_path:  Report\Clusterd\antique\documents\text\c\l.xml( 0.13338944675549325)
# add hand file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.42398839107597075)
# add mask file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 1.416590661863081)
# add see file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.07206300616759659)
# add want file_path:  Report\Clusterd\antique\documents\text\w\a.xml( 0.2591481560163773)
# add wrap file_path:  Report\Clusterd\antique\documents\text\w\r.xml( 0.24556616596753283)
# add use file_path:  Report\Clusterd\antique\documents\text\u\s.xml( 0.02862088054683681)
# add pull file_path:  Report\Clusterd\antique\documents\text\p\u.xml( 0.3408608409348816)
# add choke file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.4483294143757362)
# add guy file_path:  Report\Clusterd\antique\documents\text\g\u.xml( 0.24612209020797648)
# add part file_path:  Report\Clusterd\antique\documents\text\p\a.xml( 0.0725715908432653)
# add do file_path:  Report\Clusterd\antique\documents\text\d\o.xml( 0.036386566809246956)
# add honey file_path:  Report\Clusterd\antique\documents\text\h\o.xml( 0.71173476598622)
# add coal file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.12952897180487885)
# add code file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.16110738023050325)
# add bag file_path:  Report\Clusterd\antique\documents\text\b\a.xml( 0.3134129182538549)
# add carri file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.08201719163535559)
# add empti file_path:  Report\Clusterd\antique\documents\text\e\m.xml( 0.1447470787771148)
# add get file_path:  Report\Clusterd\antique\documents\text\g\e.xml( 0.20665208935321774)
# add dismantl file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.44921756760371884)
# add collect file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.22984992190233658)
# add hole file_path:  Report\Clusterd\antique\documents\text\h\o.xml( 0.06289859902710937)
# add villag file_path:  Report\Clusterd\antique\documents\text\v\i.xml( 0.4514084142330302)
# add big file_path:  Report\Clusterd\antique\documents\text\b\i.xml( 0.045488951618380846)
# add also file_path:  Report\Clusterd\antique\documents\text\a\l.xml( 0.07453046971829455)
# add concern file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.7000539398491666)
# add gener file_path:  Report\Clusterd\antique\documents\text\g\e.xml( 0.010918777961105474)
# add digest file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.17548920645657787)
# add wine file_path:  Report\Clusterd\antique\documents\text\w\i.xml( 0.6484021366669509)
# add miner file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.09587874830137696)
# add much file_path:  Report\Clusterd\antique\documents\text\m\u.xml( 0.40923245407068887)
# add elsewher file_path:  Report\Clusterd\antique\documents\text\e\l.xml( 0.4389247264136431)
# add meal file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.2972650465270215)
# add process file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.22796341223041292)
# add juic file_path:  Report\Clusterd\antique\documents\text\j\u.xml( 0.4826674887934984)
# add consid file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.06799474316732494)
# add china file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.09362864968266645)
# add fact file_path:  Report\Clusterd\antique\documents\text\f\a.xml( 0.061138740124960955)
# add european file_path:  Report\Clusterd\antique\documents\text\e\u.xml( 0.062235484939480605)
# add water file_path:  Report\Clusterd\antique\documents\text\w\a.xml( 0.09788546205944719)
# add ok file_path:  Report\Clusterd\antique\documents\text\o\k.xml( 0.013600525939088424)
# add stimul file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.2763310280440032)
# add belief file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.3266716731763061)
# add europ file_path:  Report\Clusterd Special\antique\documents\text\e\u.xml( 2.8945739996201247)
# add unhealthi file_path:  Report\Clusterd\antique\documents\text\u\n.xml( 0.35173408974733233)
# add dilut file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.10977145035354416)
# add drink file_path:  Report\Clusterd\antique\documents\text\d\r.xml( 0.17826605012524838)
# add veri file_path:  Report\Clusterd\antique\documents\text\v\e.xml( 0.24079602155223376)
# add near file_path:  Report\Clusterd\antique\documents\text\n\e.xml( 0.5727587612081161)
# add cycl file_path:  Report\Clusterd\antique\documents\text\c\y.xml( 0.28687384794842663)
# add natur file_path:  Report\Clusterd\antique\documents\text\n\a.xml( 0.1603360511290639)
# add includ file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.03588482175818579)
# add tap file_path:  Report\Clusterd\antique\documents\text\t\a.xml( 0.1385939103133941)
# add work file_path:  Report\Clusterd\antique\documents\text\w\o.xml( 0.007802354691585698)
# add caffein file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.27254197956458737)
# add switzerland file_path:  Report\Clusterd\antique\documents\text\s\w.xml( 0.12358435096918147)
# add tropic file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.18095574926364413)
# add child file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 2.1296446671666582)
# add avail file_path:  Report\Clusterd\antique\documents\text\a\v.xml( 0.19690112756788847)
# add upper file_path:  Report\Clusterd\antique\documents\text\u\p.xml( 0.017092705251443643)
# add block file_path:  Report\Clusterd\antique\documents\text\b\l.xml( 0.30679583173933317)
# add advertis file_path:  Report\Clusterd\antique\documents\text\a\d.xml( 0.25445469468394405)
# add comment file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.22781537771633986)
# add cold file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.28792159646062865)
# add weather file_path:  Report\Clusterd\antique\documents\text\w\e.xml( 0.6364177979367215)
# add austria file_path:  Report\Clusterd\antique\documents\text\a\u.xml( 0.09179448375695826)
# add station file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.19289637567353476)
# add car file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.3231961856672095)
# add final file_path:  Report\Clusterd\antique\documents\text\f\i.xml( 0.04605521136859649)
# add locat file_path:  Report\Clusterd\antique\documents\text\l\o.xml( 0.014529193299975852)
# add simpli file_path:  Report\Clusterd\antique\documents\text\s\i.xml( 0.07466396927976916)
# add extra file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 1.376739057914841)
# add lack file_path:  Report\Clusterd\antique\documents\text\l\a.xml( 0.11146366355284613)
# add make file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.02707992424400134)
# add extent file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.0985510180773619)
# add train file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.062145838501293106)
# add afford file_path:  Report\Clusterd\antique\documents\text\a\f.xml( 0.36366350128622293)
# add educ file_path:  Report\Clusterd\antique\documents\text\e\d.xml( 0.9099900111474686)
# add high file_path:  Report\Clusterd\antique\documents\text\h\i.xml( 0.4186872081407511)
# add usa file_path:  Report\Clusterd\antique\documents\text\u\s.xml( 0.5161065863674642)
# add peopl file_path:  Report\Clusterd\antique\documents\text\p\e.xml( 0.11302808880707096)
# add finland file_path:  Report\Clusterd\antique\documents\text\f\i.xml( 1.1958862891378195)
# add feel file_path:  Report\Clusterd\antique\documents\text\f\e.xml( 0.13166355099399507)
# add anoth file_path:  Report\Clusterd\antique\documents\text\a\n.xml( 0.1043569476840387)
# add pay file_path:  Report\Clusterd\antique\documents\text\p\a.xml( 0.04666546093277512)
# add compani file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.9041609783616578)
# add depend file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.10597584477284536)
# add ppl file_path:  Report\Clusterd\antique\documents\text\p\p.xml( 0.19805837796937723)
# add bodi file_path:  Report\Clusterd\antique\documents\text\b\o.xml( 0.1965205011377937)
# add accord file_path:  Report\Clusterd\antique\documents\text\a\c.xml( 0.10112625665246047)
# add walk file_path:  Report\Clusterd\antique\documents\text\w\a.xml( 1.5610937179645152)
# add secondli file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.14499035486347375)
# add impur file_path:  Report\Clusterd\antique\documents\text\i\m.xml( 0.29999108892989373)
# add forget file_path:  Report\Clusterd\antique\documents\text\f\o.xml( 0.11211741871681247)
# add exert file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.5436751907455167)
# add primarili file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.6497782841586542)
# add visitor file_path:  Report\Clusterd\antique\documents\text\v\i.xml( 0.162000117112678)
# add except file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.39496054451634965)
# add commod file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.502000957574782)
# add answer file_path:  Report\Clusterd\antique\documents\text\a\n.xml( 0.045009965994829704)
# add ye file_path:  Report\Clusterd\antique\documents\text\y\e.xml( 0.17609549979228664)
# add everi file_path:  Report\Clusterd\antique\documents\text\e\v.xml( 0.38108614488962583)
# add may file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.08227837777192124)
# add sever file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.05238289762257751)
# add medic file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.2675575199323661)
# add region file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.015997356571193607)
# add denmark file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.09467103336538403)
# add attract file_path:  Report\Clusterd\antique\documents\text\a\t.xml( 0.2116184684453984)
# add commut file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.2731406790349826)
# add hard file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.4009648131919125)
# add resort file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.18220607394845173)
# add hemispher file_path:  Report\Clusterd\antique\documents\text\h\e.xml( 0.36102927141328167)
# add rather file_path:  Report\Clusterd\antique\documents\text\r\a.xml( 0.28223410270141286)
# add groceri file_path:  Report\Clusterd\antique\documents\text\g\r.xml( 0.07677503986418041)
# add approach file_path:  Report\Clusterd\antique\documents\text\a\p.xml( 0.2938237868423896)
# add enough file_path:  Report\Clusterd\antique\documents\text\e\n.xml( 0.06062366270942143)
# add happen file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.10481363226179255)
# add know file_path:  Report\Clusterd\antique\documents\text\k\n.xml( 0.22516579730939962)
# add northern file_path:  Report\Clusterd\antique\documents\text\n\o.xml( 0.10510371869934979)
# add awar file_path:  Report\Clusterd\antique\documents\text\a\w.xml( 0.15542591938100742)
# add humid file_path:  Report\Clusterd\antique\documents\text\h\u.xml( 0.4978982311763448)
# add go file_path:  Report\Clusterd\antique\documents\text\g\o.xml( 0.12628187553399034)
# add certain file_path:  Report\Clusterd\antique\documents\text\c\e.xml( 0.12520559786706567)
# add easili file_path:  Report\Clusterd\antique\documents\text\e\a.xml( 0.21430009415668727)
# add thing file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 0.0782076780636063)
# add combin file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.014691081368630652)
# add compar file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.014883665490971256)
# add immun file_path:  Report\Clusterd\antique\documents\text\i\m.xml( 0.23713338118658708)
# add small file_path:  Report\Clusterd\antique\documents\text\s\m.xml( 0.16831683804080402)
# add place file_path:  Report\Clusterd\antique\documents\text\p\l.xml( 0.00999219255922186)
# add cheap file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.3117257507118844)
# add drive file_path:  Report\Clusterd\antique\documents\text\d\r.xml( 0.1569878086786168)
# add soda file_path:  Report\Clusterd\antique\documents\text\s\o.xml( 0.3085940640489244)
# add expert file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.23538371287441423)
# add due file_path:  Report\Clusterd\antique\documents\text\d\u.xml( 0.1378060621090822)
# add bottl file_path:  Report\Clusterd\antique\documents\text\b\o.xml( 0.19057599038046333)
# add differ file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.1603982538778238)
# add consum file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.13647789108422395)
# add addict file_path:  Report\Clusterd\antique\documents\text\a\d.xml( 0.16932806610964501)
# add geograph file_path:  Report\Clusterd\antique\documents\text\g\e.xml( 0.2815336048915739)
# add exampl file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.3849550650048185)
# add beer file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.8504184576631081)
# add less file_path:  Report\Clusterd\antique\documents\text\l\e.xml( 0.4196057609610251)
# add probabl file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.11300129177859985)
# add true file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.8876163031493228)
# add engag file_path:  Report\Clusterd\antique\documents\text\e\n.xml( 0.09554487418746359)
# add electr file_path:  Report\Clusterd\antique\documents\text\e\l.xml( 0.22236260312223)
# add energi file_path:  Report\Clusterd\antique\documents\text\e\n.xml( 0.19703751997804042)
# add effici file_path:  Report\Clusterd\antique\documents\text\e\f.xml( 0.11054592301741942)
# add cool file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 2.3933567981339294)
# add francisco file_path:  Report\Clusterd\antique\documents\text\f\r.xml( 0.04160690410714091)
# add two file_path:  Report\Clusterd\antique\documents\text\t\w.xml( 0.28723760527993936)
# add effect file_path:  Report\Clusterd\antique\documents\text\e\f.xml( 0.31321559935982773)
# add add file_path:  Report\Clusterd\antique\documents\text\a\d.xml( 0.024780660212519193)
# add abov file_path:  Report\Clusterd\antique\documents\text\a\b.xml( 0.264061087959064)
# add speed file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.3519161093558084)
# add benefit file_path:  Report\Clusterd\antique\documents\text\b\e.xml( 0.4407144434665049)
# add mean file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.14084605094465416)
# add system file_path:  Report\Clusterd\antique\documents\text\s\y.xml( 0.053935408556051945)
# add batteri file_path:  Report\Clusterd\antique\documents\text\b\a.xml( 1.5419801804611155)
# add chemic file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.05798325250096836)
# add visibl file_path:  Report\Clusterd\antique\documents\text\v\i.xml( 0.2981146542281811)
# add store file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.050306710399237106)
# add never file_path:  Report\Clusterd\antique\documents\text\n\e.xml( 0.20447744804346477)
# add onli file_path:  Report\Clusterd\antique\documents\text\o\n.xml( 0.0333671005321899)
# add citi file_path:  Report\Clusterd\antique\documents\text\c\i.xml( 0.8700535025090048)
# add pollut file_path:  Report\Clusterd\antique\documents\text\p\o.xml( 0.7545668450395902)
# add mostli file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 0.20882366630917218)
# add cours file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.068210962570625)
# add hybrid file_path:  Report\Clusterd\antique\documents\text\h\y.xml( 0.1736007423740156)
# add ga file_path:  Report\Clusterd\antique\documents\text\g\a.xml( 0.27154646713503994)
# add almost file_path:  Report\Clusterd\antique\documents\text\a\l.xml( 0.05836090893263898)
# add buse file_path:  Report\Clusterd\antique\documents\text\b\u.xml( 0.21347455360013232)
# add motor file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 0.3951107491890696)
# add save file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.2552312941922751)
# add close file_path:  Report\Clusterd\antique\documents\text\c\l.xml( 0.5436145875973362)
# add rpm file_path:  Report\Clusterd\antique\documents\text\r\p.xml( 0.12316416903990078)
# add quieter file_path:  Report\Clusterd\antique\documents\text\q\u.xml( 1.0008898066943996)
# add engin file_path:  Report\Clusterd\antique\documents\text\e\n.xml( 0.4538650474666497)
# add san file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.0182013987849658)
# add break file_path:  Report\Clusterd\antique\documents\text\b\r.xml( 0.05167312949670453)
# add good file_path:  Report\Clusterd\antique\documents\text\g\o.xml( 0.19734108518976842)
# add pack file_path:  Report\Clusterd\antique\documents\text\p\a.xml( 0.2408918424728385)
# add pronounc file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.21128497196485135)
# add stop file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.19764464074486013)
# add slow file_path:  Report\Clusterd\antique\documents\text\s\l.xml( 0.4866642990915443)
# add spend file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.057248432672228476)
# add chang file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.16598185858546846)
# add frequent file_path:  Report\Clusterd\antique\documents\text\f\r.xml( 0.030423287208061423)
# add mileag file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.24118394295557496)
# add move file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 0.32547380001869536)
# add assist file_path:  Report\Clusterd\antique\documents\text\a\s.xml( 0.05261633513993008)
# add light file_path:  Report\Clusterd\antique\documents\text\l\i.xml( 0.6696772901677752)
# add instead file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.3596830629214975)
# add brake file_path:  Report\Clusterd\antique\documents\text\b\r.xml( 0.017610191718604264)
# add tradit file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.1533469527141428)
# add mention file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.09410479508479112)
# add large file_path:  Report\Clusterd\antique\documents\text\l\a.xml( 0.10381283137297552)
# add without file_path:  Report\Clusterd\antique\documents\text\w\i.xml( 0.09088214604631484)
# add note file_path:  Report\Clusterd\antique\documents\text\n\o.xml( 0.04341171589987275)
# add honda file_path:  Report\Clusterd\antique\documents\text\h\o.xml( 0.02456170753360058)
# add civic file_path:  Report\Clusterd\antique\documents\text\c\i.xml( 1.061588819597369)
# add regular file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.1380742749765159)
# add measur file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.2925136211732359)
# add rate file_path:  Report\Clusterd\antique\documents\text\r\a.xml( 0.14933653402750305)
# add mass file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 1.0431513220594206)
# add squar file_path:  Report\Clusterd\antique\documents\text\s\q.xml( 0.278954896106118)
# add vise file_path:  Report\Clusterd\antique\documents\text\v\i.xml( 0.26809250545764307)
# add convers file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.06634730670634605)
# add turn file_path:  Report\Clusterd\antique\documents\text\t\u.xml( 0.14539266368379838)
# add appli file_path:  Report\Clusterd\antique\documents\text\a\p.xml( 0.025821302508456243)
# add versa file_path:  Report\Clusterd\antique\documents\text\v\e.xml( 0.20136834182075158)
# add low file_path:  Report\Clusterd\antique\documents\text\l\o.xml( 0.3337530422387627)
# add proton file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.22125689806050006)
# add critic file_path:  Report\Clusterd\antique\documents\text\c\r.xml( 0.5313248923217716)
# add allow file_path:  Report\Clusterd\antique\documents\text\a\l.xml( 0.1702374595847161)
# add einstein file_path:  Report\Clusterd\antique\documents\text\e\i.xml( 0.44811842143494474)
# add determin file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.06297611748692747)
# add neutron file_path:  Report\Clusterd\antique\documents\text\n\e.xml( 0.23421759794147973)
# add inde file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.19960775216924803)
# add breakthrough file_path:  Report\Clusterd\antique\documents\text\b\r.xml( 0.1225762616200236)
# add equal file_path:  Report\Clusterd\antique\documents\text\e\q.xml( 0.10303467535389361)
# add electron file_path:  Report\Clusterd\antique\documents\text\e\l.xml( 0.015272940526756127)
# add order file_path:  Report\Clusterd\antique\documents\text\o\r.xml( 0.07192680782334832)
# add could file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.11830148797961201)
# add amount file_path:  Report\Clusterd\antique\documents\text\a\m.xml( 0.08753587288997264)
# add relationship file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.42465309982378013)
# add theori file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 0.6511752026696402)
# add person file_path:  Report\Clusterd\antique\documents\text\p\e.xml( 0.08871505830479838)
# add show file_path:  Report\Clusterd\antique\documents\text\s\h.xml( 0.5071635255064616)
# add calcul file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.20830838976325278)
# add mc file_path:  Report\Clusterd\antique\documents\text\m\c.xml( 0.27856315400632986)
# add previou file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.25214399448890157)
# add physicist file_path:  Report\Clusterd\antique\documents\text\p\h.xml( 0.03899124067732967)
# add expans file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.17471773718461023)
# add releas file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.15103771464956328)
# add atom file_path:  Report\Clusterd\antique\documents\text\a\t.xml( 0.0676800791696055)
# add develop file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.14014205959175463)
# add bind file_path:  Report\Clusterd\antique\documents\text\b\i.xml( 0.37702248550363254)
# add matter file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.12996633609153216)
# add contain file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.30945314090983467)
# add definit file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.20169748143503208)
# add rememb file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.05996632472005708)
# add school file_path:  Report\Clusterd\antique\documents\text\s\c.xml( 0.22637344139161925)
# add field file_path:  Report\Clusterd\antique\documents\text\f\i.xml( 0.17013176620661402)
# add weight file_path:  Report\Clusterd\antique\documents\text\w\e.xml( 0.7364174763489014)
# add ap file_path:  Report\Clusterd\antique\documents\text\a\p.xml( 0.49153911853086596)
# add formula file_path:  Report\Clusterd\antique\documents\text\f\o.xml( 0.918577001646139)
# add anymor file_path:  Report\Clusterd\antique\documents\text\a\n.xml( 0.1069529554675742)
# add gpa file_path:  Report\Clusterd\antique\documents\text\g\p.xml( 0.4234309002068809)
# add interest file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.06277647368015375)
# add univers file_path:  Report\Clusterd\antique\documents\text\u\n.xml( 0.18864471772524327)
# add ultim file_path:  Report\Clusterd\antique\documents\text\u\l.xml( 0.20008129037618286)
# add admiss file_path:  Report\Clusterd\antique\documents\text\a\d.xml( 1.9755956205077694)
# add major file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.2757315227077689)
# add play file_path:  Report\Clusterd\antique\documents\text\p\l.xml( 0.11654278154125731)
# add though file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 0.11988813284402657)
# add put file_path:  Report\Clusterd\antique\documents\text\p\u.xml( 0.2757705071366995)
# add everyon file_path:  Report\Clusterd\antique\documents\text\e\v.xml( 0.1159659615201492)
# add grade file_path:  Report\Clusterd\antique\documents\text\g\r.xml( 0.10118040061827215)
# add class file_path:  Report\Clusterd\antique\documents\text\c\l.xml( 0.19051318626841734)
# add offic file_path:  Report\Clusterd\antique\documents\text\o\f.xml( 0.026829775473231003)
# add chanc file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.5094212453876178)
# add colleg file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.20687493647492233)
# add specif file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.013007446656200251)
# add score file_path:  Report\Clusterd\antique\documents\text\s\c.xml( 0.06733422506939524)
# add give file_path:  Report\Clusterd\antique\documents\text\g\i.xml( 0.11905184695695073)
# add suggest file_path:  Report\Clusterd\antique\documents\text\s\u.xml( 0.07137325812396719)
# add state file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.049398640510629574)
# add case file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.20799777063907987)
# add budget file_path:  Report\Clusterd\antique\documents\text\b\u.xml( 0.17230914483972928)
# add reflect file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.16882491539676517)
# add select file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.22932875171857006)
# add holist file_path:  Report\Clusterd\antique\documents\text\h\o.xml( 0.3105265294373931)
# add multipli file_path:  Report\Clusterd\antique\documents\text\m\u.xml( 1.0373540645693224)
# add standard file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.4474066852089111)
# add earn file_path:  Report\Clusterd\antique\documents\text\e\a.xml( 0.31331206334956613)
# add price file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.17406211814318948)
# add rank file_path:  Report\Clusterd\antique\documents\text\r\a.xml( 0.042742149812100734)
# add look file_path:  Report\Clusterd\antique\documents\text\l\o.xml( 0.12437405728420402)
# add well file_path:  Report\Clusterd\antique\documents\text\w\e.xml( 0.40112956136640293)
# add difficulti file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.3509793217466128)
# add addit file_path:  Report\Clusterd\antique\documents\text\a\d.xml( 0.06128386031101477)
# add evid file_path:  Report\Clusterd\antique\documents\text\e\v.xml( 0.03323914163372666)
# add darn file_path:  Report\Clusterd\antique\documents\text\d\a.xml( 0.8874344312061391)
# add instanc file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.08257362403528375)
# add wait file_path:  Report\Clusterd\antique\documents\text\w\a.xml( 2.440662163366236)
# add listen file_path:  Report\Clusterd\antique\documents\text\l\i.xml( 0.24037149648345213)
# add overal file_path:  Report\Clusterd\antique\documents\text\o\v.xml( 0.2073511794661971)
# add fema file_path:  Report\Clusterd\antique\documents\text\f\e.xml( 0.23260333695512697)
# add nation file_path:  Report\Clusterd\antique\documents\text\n\a.xml( 0.061821145443279026)
# add articl file_path:  Report\Clusterd\antique\documents\text\a\r.xml( 0.016049219721754313)
# add local file_path:  Report\Clusterd\antique\documents\text\l\o.xml( 0.45877874882213227)
# add last file_path:  Report\Clusterd\antique\documents\text\l\a.xml( 0.045748127686536376)
# add bungl file_path:  Report\Clusterd\antique\documents\text\b\u.xml( 0.73287160683392)
# add send file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.012848559298741985)
# add guard file_path:  Report\Clusterd\antique\documents\text\g\u.xml( 0.21222192516738475)
# add felt file_path:  Report\Clusterd\antique\documents\text\f\e.xml( 0.5145895202266433)
# add run file_path:  Report\Clusterd\antique\documents\text\r\u.xml( 0.109885613696198)
# add evacu file_path:  Report\Clusterd\antique\documents\text\e\v.xml( 0.11308371984108109)
# add commun file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.056774489109973535)
# add realli file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.08772718973693906)
# add polic file_path:  Report\Clusterd\antique\documents\text\p\o.xml( 0.06410856130191167)
# add night file_path:  Report\Clusterd\antique\documents\text\n\i.xml( 0.2404688214470169)
# add hey file_path:  Report\Clusterd\antique\documents\text\h\e.xml( 0.2214690743040379)
# add npr file_path:  Report\Clusterd\antique\documents\text\n\p.xml( 0.557719196455057)
# add sure file_path:  Report\Clusterd\antique\documents\text\s\u.xml( 0.1288740253671498)
# add organ file_path:  Report\Clusterd\antique\documents\text\o\r.xml( 0.049242879972763234)
# add dollar file_path:  Report\Clusterd\antique\documents\text\d\o.xml( 1.253989754205829)
# add dwindl file_path:  Report\Clusterd\antique\documents\text\d\w.xml( 0.125020692627628)
# add manag file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.09858613983192116)
# add senat file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.0401963216345277)
# add surpris file_path:  Report\Clusterd\antique\documents\text\s\u.xml( 0.3314275943340665)
# add miser file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.22103748859136663)
# add issu file_path:  Report\Clusterd\antique\documents\text\i\s.xml( 0.07297229861276816)
# add rescu file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.0991287324384307)
# add job file_path:  Report\Clusterd\antique\documents\text\j\o.xml( 0.17266618964464392)
# add fail file_path:  Report\Clusterd\antique\documents\text\f\a.xml( 0.6234702089557869)
# add flag file_path:  Report\Clusterd\antique\documents\text\f\l.xml( 0.3129132789229876)
# add feder file_path:  Report\Clusterd\antique\documents\text\f\e.xml( 0.5676764911936131)
# add thousand file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 0.032262001173832794)
# add armi file_path:  Report\Clusterd\antique\documents\text\a\r.xml( 0.14923344239519967)
# add shout file_path:  Report\Clusterd Special\antique\documents\text\s\h.xml( 3.771584204178315)
# add aircraft file_path:  Report\Clusterd\antique\documents\text\a\i.xml( 0.17172243844390725)
# add reelect file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 2.452059342732969)
# add possibl file_path:  Report\Clusterd\antique\documents\text\p\o.xml( 0.09088084690513351)
# add transport file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.16519180164382116)
# add red file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.19276308429911637)
# add blame file_path:  Report\Clusterd\antique\documents\text\b\l.xml( 0.5461845841864792)
# add ask file_path:  Report\Clusterd\antique\documents\text\a\s.xml( 0.13171022812433797)
# add doubt file_path:  Report\Clusterd\antique\documents\text\d\o.xml( 0.08124152214465924)
# add bite file_path:  Report\Clusterd\antique\documents\text\b\i.xml( 0.4409499997381233)
# add hear file_path:  Report\Clusterd\antique\documents\text\h\e.xml( 0.241002003230423)
# add anim file_path:  Report\Clusterd\antique\documents\text\a\n.xml( 0.05686934570159724)
# add frequenc file_path:  Report\Clusterd\antique\documents\text\f\r.xml( 0.8125589052347063)
# add sound file_path:  Report\Clusterd\antique\documents\text\s\o.xml( 0.18808674547144563)
# add home file_path:  Report\Clusterd\antique\documents\text\h\o.xml( 0.11545707299166945)
# add rang file_path:  Report\Clusterd\antique\documents\text\r\a.xml( 0.12087267223360441)
# add eleph file_path:  Report\Clusterd\antique\documents\text\e\l.xml( 0.4067989858983595)
# add infrasound file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.5233154756753513)
# add distanc file_path:  Report\Clusterd\antique\documents\text\d\i.xml( 0.08807045417445773)
# add whale file_path:  Report\Clusterd\antique\documents\text\w\h.xml( 0.5777606157168323)
# add expand file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.1242459720678217)
# add varieti file_path:  Report\Clusterd\antique\documents\text\v\a.xml( 0.02836132560028066)
# ...
# add classifi file_path:  Report\Clusterd\antique\documents\text\c\l.xml( 0.033489414725071665)
# add staphylococci file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.171916656978594)
# add acquir file_path:  Report\Clusterd\antique\documents\text\a\c.xml( 0.10618916970402072)
# add chlamydia file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.26393136574591913)
# add gram file_path:  Report\Clusterd\antique\documents\text\g\r.xml( 1.805800188460405)
# add blind file_path:  Report\Clusterd\antique\documents\text\b\l.xml( 0.17400708181698543)
# add braill file_path:  Report\Clusterd\antique\documents\text\b\r.xml( 0.14940661020291507)
# add camcord file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 1.2677161606919265)
# add cam file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.6214810162217691)
# add videocd file_path:  Report\Clusterd\antique\documents\text\v\i.xml( 0.6781157025266763)
# add usbav file_path:  Report\Clusterd\antique\documents\text\u\s.xml( 0.6781157025266763)
# add video file_path:  Report\Clusterd\antique\documents\text\v\i.xml( 0.1553778972671335)
# add odd file_path:  Report\Clusterd\antique\documents\text\o\d.xml( 0.055645068740383)
# add realist file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.3544994541309927)
# add lotteri file_path:  Report\Clusterd\antique\documents\text\l\o.xml( 0.19208191561028465)
# add slim file_path:  Report\Clusterd\antique\documents\text\s\l.xml( 0.18811215674868478)
# add account file_path:  Report\Clusterd\antique\documents\text\a\c.xml( 0.26956359712984346)
# add struck file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.13904172959883274)
# add strike file_path:  Report\Clusterd\antique\documents\text\s\t.xml( 0.26602174958249025)
# add cocoa file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.08581011529483644)
# add dermatologist file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.1181279919666013)
# add olay file_path:  Report\Clusterd\antique\documents\text\o\l.xml( 0.540010657667099)
# add quench file_path:  Report\Clusterd\antique\documents\text\q\u.xml( 0.7256591476675459)
# add heal file_path:  Report\Clusterd\antique\documents\text\h\e.xml( 0.37462290092658146)
# add gentl file_path:  Report\Clusterd\antique\documents\text\g\e.xml( 1.2206559169882134)
# add movant file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 1.0466309513507026)
# add lawsuit file_path:  Report\Clusterd\antique\documents\text\l\a.xml( 0.7208883145379839)
# add proceed file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.09349893524929087)
# add hectic file_path:  Report\Clusterd\antique\documents\text\h\e.xml( 0.46705892242532737)
# add newspap file_path:  Report\Clusterd\antique\documents\text\n\e.xml( 0.6224124387415936)
# add singl file_path:  Report\Clusterd\antique\documents\text\s\i.xml( 0.12234966599125813)
# add happend file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.4081655667826876)
# add moon file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 0.2971701483633202)
# add calendar file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.15433074711478603)
# add nasa file_path:  Report\Clusterd\antique\documents\text\n\a.xml( 0.03913030267219205)
# add indian file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.2260677400647452)
# add mainstream file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.020146664153122086)
# add bay file_path:  Report\Clusterd\antique\documents\text\b\a.xml( 0.06642084932318254)
# add thai file_path:  Report\Clusterd\antique\documents\text\t\h.xml( 1.462040904707732)
# add garam file_path:  Report\Clusterd\antique\documents\text\g\a.xml( 0.33905785126333815)
# add exept file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.0990776650604333)
# add sa file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.2656790546946649)
# add reali file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.2853532969157465)
# add masala file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.11007256633519422)
# add spici file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.22193743945240246)
# add chloramphenicol file_path:  Report\Clusterd\antique\documents\text\c\h.xml( 0.34874521844229067)
# add cephalosporin file_path:  Report\Clusterd\antique\documents\text\c\e.xml( 0.73287160683392)
# add penicillin file_path:  Report\Clusterd Special\antique\documents\text\p\e.xml( 8.772245428246393)
# add motil file_path:  Report\Clusterd\antique\documents\text\m\o.xml( 0.22671662916801194)
# add sulfamethoxazol file_path:  Report\Clusterd\antique\documents\text\s\u.xml( 0.34874521844229067)
# add ciprofloxacin file_path:  Report\Clusterd\antique\documents\text\c\i.xml( 0.34874521844229067)
# add facult file_path:  Report\Clusterd\antique\documents\text\f\a.xml( 0.31980390180160356)
# add nitrit file_path:  Report\Clusterd\antique\documents\text\n\i.xml( 0.17684897412542291)
# add typhi file_path:  Report\Clusterd\antique\documents\text\t\y.xml( 0.1555802765521315)
# add anaerob file_path:  Report\Clusterd\antique\documents\text\a\n.xml( 0.032165597242558866)
# add trimethoprim file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.34874521844229067)
# add nonsporul file_path:  Report\Clusterd\antique\documents\text\n\o.xml( 0.34874521844229067)
# add bacillu file_path:  Report\Clusterd\antique\documents\text\b\a.xml( 0.14718967745505876)
# add flagellum file_path:  Report\Clusterd\antique\documents\text\f\l.xml( 1.8006441001861242)
# add flagel file_path:  Report\Clusterd\antique\documents\text\f\l.xml( 0.20036672748329237)
# add azithromycin file_path:  Report\Clusterd\antique\documents\text\a\z.xml( 0.23036227679665397)
# add salmonella file_path:  Report\Clusterd\antique\documents\text\s\a.xml( 0.1387289547011485)
# add peritrich file_path:  Report\Clusterd\antique\documents\text\p\e.xml( 0.34874521844229067)
# add ampicillin file_path:  Report\Clusterd\antique\documents\text\a\m.xml( 0.3488769837835676)
# add ferment file_path:  Report\Clusterd\antique\documents\text\f\e.xml( 0.14076680244578696)
# add quinolon file_path:  Report\Clusterd\antique\documents\text\q\u.xml( 0.34874521844229067)
# add synthes file_path:  Report\Clusterd\antique\documents\text\s\y.xml( 0.08293470210134099)
# add nitrat file_path:  Report\Clusterd\antique\documents\text\n\i.xml( 0.5748492459975783)
# add rd file_path:  Report\Clusterd\antique\documents\text\r\d.xml( 0.058005743612242325)
# add nonencapsul file_path:  Report\Clusterd\antique\documents\text\n\o.xml( 0.34874521844229067)
# add mexico file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.3979303691512556)
# add drcovarrubia file_path:  Report\Clusterd\antique\documents\text\d\r.xml( 0.8718630461057267)
# add gentamicin file_path:  Report\Clusterd\antique\documents\text\g\e.xml( 0.8718630461057267)
# add hello file_path:  Report\Clusterd\antique\documents\text\h\e.xml( 1.3538295340215267)
# add norfloxacin file_path:  Report\Clusterd\antique\documents\text\n\o.xml( 0.8718630461057267)
# add tellm file_path:  Report\Clusterd\antique\documents\text\t\e.xml( 0.8718630461057267)
# add marin file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.03314206164257785)
# add merchant file_path:  Report\Clusterd\antique\documents\text\m\e.xml( 0.23458590293444886)
# add cruiselin file_path:  Report\Clusterd\antique\documents\text\c\r.xml( 0.35977938952680405)
# add wdisney file_path:  Report\Clusterd\antique\documents\text\w\d.xml( 2.034347107580029)
# add uncommon file_path:  Report\Clusterd\antique\documents\text\u\n.xml( 0.26672399894507687)
# add declin file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.36293333544702455)
# add liabl file_path:  Report\Clusterd\antique\documents\text\l\i.xml( 0.05587309576828258)
# add indemn file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.6364590167116346)
# add justifi file_path:  Report\Clusterd\antique\documents\text\j\u.xml( 0.07826458998181515)
# add automobil file_path:  Report\Clusterd\antique\documents\text\a\u.xml( 0.11962585779076831)
# add coverag file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.5415439071199225)
# add shield file_path:  Report\Clusterd\antique\documents\text\s\h.xml( 0.12309437979058052)
# add indemnifi file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 1.7712216099781124)
# add hotlin file_path:  Report\Clusterd\antique\documents\text\h\o.xml( 0.16134569317897246)
# add complaint file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.9263614892448823)
# add civilian file_path:  Report\Clusterd\antique\documents\text\c\i.xml( 0.06277688262089513)
# add shatter file_path:  Report\Clusterd\antique\documents\text\s\h.xml( 0.5645745336091745)
# add boom file_path:  Report\Clusterd\antique\documents\text\b\o.xml( 0.22829647470668893)
# add earthquak file_path:  Report\Clusterd\antique\documents\text\e\a.xml( 0.07081652937173501)
# add shelv file_path:  Report\Clusterd\antique\documents\text\s\h.xml( 0.10270863397930742)
# add alarm file_path:  Report\Clusterd\antique\documents\text\a\l.xml( 0.228637290404957)
# add pilot file_path:  Report\Clusterd\antique\documents\text\p\i.xml( 0.3292703525543007)
# add sonic file_path:  Report\Clusterd\antique\documents\text\s\o.xml( 0.18119818705684096)
# add altitud file_path:  Report\Clusterd\antique\documents\text\a\l.xml( 0.03165444505036661)
# add mach file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.2210958638452224)
# add concord file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.0937254205430834)
# add halt file_path:  Report\Clusterd\antique\documents\text\h\a.xml( 0.023634948991317663)
# add spill file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.11803147371622527)
# add admir file_path:  Report\Clusterd\antique\documents\text\a\d.xml( 0.4155141480238632)
# add congressman file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.12991409869023055)
# add grandma file_path:  Report\Clusterd\antique\documents\text\g\r.xml( 0.4138240604024346)
# add jet file_path:  Report\Clusterd\antique\documents\text\j\e.xml( 0.32620020126544674)
# add fierc file_path:  Report\Clusterd\antique\documents\text\f\i.xml( 0.10443149319340943)
# add traffic file_path:  Report\Clusterd\antique\documents\text\t\r.xml( 0.4305610704207591)
# add prohibit file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.05396465426952732)
# add nephew file_path:  Report\Clusterd\antique\documents\text\n\e.xml( 0.19936921427832713)
# add kasner file_path:  Report\Clusterd\antique\documents\text\k\a.xml( 0.19349479772870132)
# add immens file_path:  Report\Clusterd\antique\documents\text\i\m.xml( 0.36797766969621776)
# add mathematician file_path:  Report\Clusterd\antique\documents\text\m\a.xml( 0.16217631537430632)
# add sirotta file_path:  Report\Clusterd\antique\documents\text\s\i.xml( 0.5233154756753513)
# add milton file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.540068388534987)
# add coin file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.46025181518428476)
# add googol file_path:  Report\Clusterd Special\antique\documents\text\g\o.xml( 2.531669025709467)
# add mission file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.10358514760625985)
# add googolplex file_path:  Report\Clusterd\antique\documents\text\g\o.xml( 0.1070370175014756)
# add numb file_path:  Report\Clusterd\antique\documents\text\n\u.xml( 0.08329566540196534)
# add artwork file_path:  Report\Clusterd\antique\documents\text\a\r.xml( 0.5546258203027179)
# add basicli file_path:  Report\Clusterd\antique\documents\text\b\a.xml( 0.2867069764198191)
# add preferabali file_path:  Report\Clusterd\antique\documents\text\p\r.xml( 0.5548219384309171)
# add weatherproof file_path:  Report\Clusterd\antique\documents\text\w\e.xml( 0.13712938711928477)
# add labl file_path:  Report\Clusterd\antique\documents\text\l\a.xml( 0.22051746812771586)
# add illustr file_path:  Report\Clusterd\antique\documents\text\i\l.xml( 0.6807398740620614)
# add photoshop file_path:  Report\Clusterd\antique\documents\text\p\h.xml( 1.0031270897078197)
# add syring file_path:  Report\Clusterd\antique\documents\text\s\y.xml( 0.21558358059255672)
# add irrig file_path:  Report\Clusterd\antique\documents\text\i\r.xml( 0.20052880674334125)
# add peroxid file_path:  Report\Clusterd\antique\documents\text\p\e.xml( 0.11617542029798808)
# add butther file_path:  Report\Clusterd\antique\documents\text\b\u.xml( 0.5005626289068578)
# add earwax file_path:  Report\Clusterd Special\antique\documents\text\e\a.xml( 4.860615496814883)
# add candl file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.5089627109051964)
# add pik file_path:  Report\Clusterd\antique\documents\text\p\i.xml( 0.44152769719358675)
# add perioxid file_path:  Report\Clusterd\antique\documents\text\p\e.xml( 0.6396078036032071)
# add sender file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.2878264177020021)
# add decod file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.48580144930879493)
# add island file_path:  Report\Clusterd\antique\documents\text\i\s.xml( 0.15798821147004863)
# add citru file_path:  Report\Clusterd\antique\documents\text\c\i.xml( 0.2652644113494408)
# add min file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.2621553689693626)
# add arob file_path:  Report\Clusterd\antique\documents\text\a\r.xml( 0.5409901642048894)
# add exersis file_path:  Report\Clusterd\antique\documents\text\e\x.xml( 0.42604314988291825)
# add session file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.2366207350671059)
# add workout file_path:  Report\Clusterd\antique\documents\text\w\o.xml( 0.24073312189574994)
# add jog file_path:  Report\Clusterd\antique\documents\text\j\o.xml( 0.812100846429914)
# add bout file_path:  Report\Clusterd\antique\documents\text\b\o.xml( 0.32222356729594825)
# add repeeat file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.3937446014671024)
# add cardio file_path:  Report\Clusterd\antique\documents\text\c\a.xml( 0.2470147318816903)
# add sprint file_path:  Report\Clusterd\antique\documents\text\s\p.xml( 0.10191795980226517)
# add interv file_path:  Report\Clusterd\antique\documents\text\i\n.xml( 0.47068940990307684)
# add server file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.16621894047459854)
# add sql file_path:  Report\Clusterd\antique\documents\text\s\q.xml( 0.26446381801576346)
# add comma file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 1.0481743244086774)
# add databs file_path:  Report\Clusterd\antique\documents\text\d\a.xml( 0.29062101536857554)
# add semicolon file_path:  Report\Clusterd\antique\documents\text\s\e.xml( 0.07257989542908276)
# add ms file_path:  Report\Clusterd\antique\documents\text\m\s.xml( 0.8419757873967334)
# add bundl file_path:  Report\Clusterd\antique\documents\text\b\u.xml( 0.045649148679136)
# add microsoft file_path:  Report\Clusterd\antique\documents\text\m\i.xml( 0.03962594374758874)
# add geotherm file_path:  Report\Clusterd\antique\documents\text\g\e.xml( 1.3887472848042521)
# add layer file_path:  Report\Clusterd\antique\documents\text\l\a.xml( 0.08891871183286598)
# add recollect file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.6943736424021261)
# add turbin file_path:  Report\Clusterd\antique\documents\text\t\u.xml( 0.3444897333326294)
# add defram file_path:  Report\Clusterd\antique\documents\text\d\e.xml( 0.6103041322740088)
# add confin file_path:  Report\Clusterd\antique\documents\text\c\o.xml( 0.15548571490034946)
# add util file_path:  Report\Clusterd\antique\documents\text\u\t.xml( 0.35297213974099095)
# add efect file_path:  Report\Clusterd\antique\documents\text\e\f.xml( 0.4606298860941248)
# add piezo file_path:  Report\Clusterd\antique\documents\text\p\i.xml( 0.8856108049890562)
# add temp file_path:  Report\Clusterd\antique\documents\text\t\e.xml( 0.07655444645015556)
# add nozzl file_path:  Report\Clusterd\antique\documents\text\n\o.xml( 0.23758273177290468)
# add pipe file_path:  Report\Clusterd\antique\documents\text\p\i.xml( 0.08042957687790676)
# add reheat file_path:  Report\Clusterd\antique\documents\text\r\e.xml( 0.5479879931248114)
