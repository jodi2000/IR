# %%
from flask import Flask, request, jsonify
from flask_cors import CORS

app = Flask(__name__)
CORS(app)

@app.route("/")
def home():
    return "Hello, World!sssssss"

@app.route('/predict', methods=['POST'])
def predict():
    dataset_name = request.json.get('dataset_name')

    response = {
        'dataset_name': dataset_name
    }
    
    return jsonify(response)

@app.route('/search',methods=['GET'])
def search():
    search = request.args.get('search')  # Get query parameter from URL
    results = [
        {
            'doc_id': '1',
            'title': 'Title 1',
            'condition': 'Condition 1',
            'summary': 'Summary 1',
            'detailed_description': 'Detailed description 1',
            'eligibility': 'Eligibility 1'
        },
        {
            'doc_id': '2',
            'title': 'Title 2',
            'condition': 'Condition 2',
            'summary': 'Summary 2',
            'detailed_description': 'Detailed description 2',
            'eligibility': 'Eligibility 2'
        }
    ]
    suggestions = [
        {'id': '1', 'text': 'Suggestion 1'},
        {'id': '2', 'text': 'Suggestion 2'}
    ]
    
    response = {
        'results': results,
        'suggestions': suggestions
    }
    
    return jsonify(response)

if __name__ == '__main__':
    app.run(port=8080)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8080
# Press CTRL+C to quit
# 127.0.0.1 - - [01/Jun/2024 12:52:17] "GET /search?search=dd HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:53:14] "OPTIONS /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:53:14] "GET /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:53:39] "OPTIONS /search?search=a HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:53:39] "GET /search?search=a HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:53:41] "OPTIONS /search?search=aa HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:53:41] "GET /search?search=aa HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:53:44] "GET /search?search=aa HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:05] "OPTIONS /search?search=s HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:05] "GET /search?search=s HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:47] "OPTIONS /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:47] "GET /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:48] "OPTIONS /search?search=s HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:48] "GET /search?search=s HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:49] "GET /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:49] "OPTIONS /search?search=w HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:49] "GET /search?search=w HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:51] "GET /search?search=w HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:53] "OPTIONS /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:53] "GET /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:55] "OPTIONS /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:55] "GET /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:56] "GET /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:55:57] "GET /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:01] "OPTIONS /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:01] "GET /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:02] "OPTIONS /search?search=ts HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:02] "GET /search?search=ts HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:02] "GET /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:02] "GET /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:03] "GET /search?search=t HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:05] "OPTIONS /search?search=d HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:05] "GET /search?search=d HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:11] "OPTIONS /search?search=d HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:56:11] "GET /search?search=d HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:58:08] "OPTIONS /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:58:08] "GET /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:59:26] "OPTIONS /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 12:59:26] "GET /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 13:00:51] "OPTIONS /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 13:00:51] "GET /search?search= HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 13:01:03] "OPTIONS /search?search=s HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 13:01:03] "GET /search?search=s HTTP/1.1" 200 -
# 127.0.0.1 - - [01/Jun/2024 13:01:04] "GET /search?search=s HTTP/1.1" 200 -
